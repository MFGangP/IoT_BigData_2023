# %% [markdown]
# ### 스타벅스 서울 매장 위치 크롤링
#
# #### 사용 모듈
# - 셀레니움
# - 뷰티플 수프
# - 판다스
# - 포리움

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\source\iot_bigdata_2023\da_env\lib\site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\source\iot_bigdata_2023\da_env\lib\site-packages (from beautifulsoup4) (2.4.1)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
driver = webdriver.Chrome()
url = 'https://www.starbucks.co.kr/store/store_map.do?disp=locale'
driver.get(url)

# %% [markdown]
# ##### Web Driver 자동 선택
#
# - html 소스를 확인 - 값이 동적으로 변경되는 부분
# - CSS_SELECTOR 구문 검색 방법
#     (# 아이디(페이지 상에 유일함), . 클래스(여러개))
#     EX) #container > div > form > fieldset > div > section > article.find_store_cont > article > article.nth-child(4) > div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(1) > a

# %%
btn_seoul_link = '#container > div > form > fieldset > div > section > article.find_store_cont >' + \
            ' article > article:nth-child(4) > div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(1) > a'
driver.find_element(By.CSS_SELECTOR, btn_seoul_link).click()

# %%
btn_all = '#mCSB_2_container > ul > li:nth-child(1) > a'
driver.find_element(By.CSS_SELECTOR, btn_all).click()

# %% [markdown]
# ##### BeautifulSoup로 html 크롤링

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
len(soup.select('li.quickResultLstCon'))
# Out:
# 601

# %%
sb_seoul_list = soup.select('li.quickResultLstCon')
sb_seoul_list

# %%
sb_seoul_list[0]
# Out:
# <li class="quickResultLstCon" data-code="3762" data-hlytag="null" data-index="0" data-lat="37.501087" data-long="127.043069" data-name="역삼아레나빌딩" data-storecd="1509" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="역삼아레나빌딩" data-store="1509" data-yn="N">역삼아레나빌딩  </strong> <p class="result_details">서울특별시 강남구 언주로 425 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>

# %%
# 매장 정보
sb_store = sb_seoul_list[0]
name = sb_store.select('strong')[0].text.strip() # 매장 이름
lat = sb_store['data-lat'] # 매장 위치 위도 값
lng = sb_store['data-long'] # 경도 값
address = sb_store.select('p')[0].get_text(separator='|').split('|')[0]
tel = sb_store.select('p')[0].get_text(separator='|').split('|')[1]
type = sb_store.select('i')[0]['class'][0].split('_')[1] # 매장 타입

print(name)
print(lat, lng)
print(type, address, tel, sep=' / ')
# Out:
# 역삼아레나빌딩
# 37.501087 127.043069
# general / 서울특별시 강남구 언주로 425 (역삼동) / 1522-3232

# %%
sb_list = []

for item in sb_seoul_list:
    name = item.select('strong')[0].text.strip() # 매장 이름
    lat = item['data-lat'] # 매장 위치 위도 값
    lng = item['data-long'] # 경도 값
    address = item.select('p')[0].get_text(separator='|').split('|')[0]
    tel = item.select('p')[0].get_text(separator='|').split('|')[1]
    type = item.select('i')[0]['class'][0].split('_')[1] # 매장 타입

    sb_list.append([name, lat, lng, address, tel, type])

# %% [markdown]
# ##### tqdm
#
# 프로그래스 바로 진행 상황을 표시해주는 모듈
#
# ```
# !pip install tqdm
# ```

# %%
# !pip install tqdm

# %%
from tqdm.autonotebook import tqdm
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13476\987820437.py:1: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
sb_list = []

for item in tqdm(sb_seoul_list):
    name = item.select('strong')[0].text.strip() # 매장 이름
    lat = item['data-lat'] # 매장 위치 위도 값
    lng = item['data-long'] # 경도 값
    address = item.select('p')[0].get_text(separator='|').split('|')[0]
    tel = item.select('p')[0].get_text(separator='|').split('|')[1]
    type = item.select('i')[0]['class'][0].split('_')[1] # 매장 타입

    sb_list.append([name, lat, lng, address, tel, type])
# Out:
#   0%|          | 0/601 [00:00<?, ?it/s]

# %%
len(sb_list)
# Out:
# 601

# %%
# DataFrame에 저장
columns = ['매장명', '위도', '경도', '주소', '전화번호', '매장 타입']
df_sb_seoul = pd.DataFrame(data=sb_list, columns=columns)

# %%
df_sb_seoul
# Out:
#          매장명                 위도                  경도  \
# 0    역삼아레나빌딩          37.501087          127.043069
# 1     논현역사거리          37.510178          127.022223
# 2    신사역성일빌딩         37.5139309         127.0206057
# 3     국기원사거리          37.499517          127.031495
# 4    대치재경빌딩R          37.494668          127.062583
# ..       ...                ...                 ...
# 596     사가정역          37.579594          127.087966
# 597      상봉역           37.59689           127.08647
# 598       묵동          37.615368          127.076633
# 599      양원역   37.6066536267232    127.106359790053
# 600      중화역  37.60170912407773  127.07841136432036
#
#                                         주소       전화번호    매장 타입
# 0                  서울특별시 강남구 언주로 425 (역삼동)  1522-3232  general
# 1                 서울특별시 강남구 강남대로 538 (논현동)  1522-3232  general
# 2                 서울특별시 강남구 강남대로 584 (논현동)  1522-3232  general
# 3                 서울특별시 강남구 테헤란로 125 (역삼동)  1522-3232  general
# 4               서울특별시 강남구 남부순환로 2947 (대치동)  1522-3232  reserve
# ..                                     ...        ...      ...
# 596                      서울특별시 중랑구 면목로 310  1522-3232  general
# 597                서울특별시 중랑구 망우로 307 (상봉동)  1522-3232  general
# 598  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  1522-3232  general
# 599              서울특별시 중랑구 양원역로10길 3 (망우동)  1522-3232  general
# 600                     서울특별시 중랑구 봉화산로 35   1522-3232  general
#
# [601 rows x 6 columns]

# %%
df_sb_seoul.head()

# %%
df_sb_seoul.tail()

# %%
df_sb_seoul.info()

# %%
df_sb_seoul.to_excel('./starbucks_seoul.xlsx', index=False)

# %% [markdown]
# #### 전처리 및 시각화
#
# - 지도 모듈 설치
#     - folium
#
# ```python
# !pip install folium
# ```

# %%
# !pip install folium

# %%
df_sb_seoul['주소'][600].split()[1]
# Out:
# '중랑구'

# %%
gu_list=[]

for item in df_sb_seoul['주소']:
    gu = item.split()[1]
    gu_list.append(gu)

# %%
df_sb_seoul['구'] = gu_list

# %%
df_sb_seoul
# Out:
#          매장명                 위도                  경도  \
# 0    역삼아레나빌딩          37.501087          127.043069
# 1     논현역사거리          37.510178          127.022223
# 2    신사역성일빌딩         37.5139309         127.0206057
# 3     국기원사거리          37.499517          127.031495
# 4    대치재경빌딩R          37.494668          127.062583
# ..       ...                ...                 ...
# 596     사가정역          37.579594          127.087966
# 597      상봉역           37.59689           127.08647
# 598       묵동          37.615368          127.076633
# 599      양원역   37.6066536267232    127.106359790053
# 600      중화역  37.60170912407773  127.07841136432036
#
#                                         주소       전화번호    매장 타입    구
# 0                  서울특별시 강남구 언주로 425 (역삼동)  1522-3232  general  강남구
# 1                 서울특별시 강남구 강남대로 538 (논현동)  1522-3232  general  강남구
# 2                 서울특별시 강남구 강남대로 584 (논현동)  1522-3232  general  강남구
# 3                 서울특별시 강남구 테헤란로 125 (역삼동)  1522-3232  general  강남구
# 4               서울특별시 강남구 남부순환로 2947 (대치동)  1522-3232  reserve  강남구
# ..                                     ...        ...      ...  ...
# 596                      서울특별시 중랑구 면목로 310  1522-3232  general  중랑구
# 597                서울특별시 중랑구 망우로 307 (상봉동)  1522-3232  general  중랑구
# 598  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  1522-3232  general  중랑구
# 599              서울특별시 중랑구 양원역로10길 3 (망우동)  1522-3232  general  중랑구
# 600                     서울특별시 중랑구 봉화산로 35   1522-3232  general  중랑구
#
# [601 rows x 7 columns]

# %% [markdown]
# #### 대한민국 행정구역 위경도 전처리

# %%
df_loc = pd.read_excel('./대한민국_행정구역_위경도.xlsx')
df_loc
# Out:
#       docity  do   city   longitude   latitude
# 0      강원강릉시  강원    강릉시  128.878497  37.749136
# 1      강원고성군  강원    고성군  128.470164  38.377961
# 2      강원동해시  강원    동해시  129.116633  37.521931
# 3      강원삼척시  강원    삼척시  129.167489  37.447086
# 4      강원속초시  강원    속초시  128.594167  38.204275
# ..       ...  ..    ...         ...        ...
# 290    충청충주시  충청    충주시  127.928144  36.988181
# 291    충청태안군  충청    태안군  126.299975  36.742667
# 292  충청한누리대로  충청  한누리대로  127.289926  36.485450
# 293    충청홍성군  충청    홍성군  126.662908  36.598361
# 294    충청대전시  충청    대전시  127.384862  36.350630
#
# [295 rows x 5 columns]

# %%
df_loc_seoul = df_loc[df_loc['do'] == '서울']
df_loc_seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 138 to 162
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   docity     25 non-null     object
#  1   do         25 non-null     object
#  2   city       25 non-null     object
#  3   longitude  25 non-null     float64
#  4   latitude   25 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 1.2+ KB

# %%
df_loc_seoul.reindex()
# Out:
#      docity  do  city   longitude   latitude
# 138   서울강남구  서울   강남구  127.049556  37.514575
# 139   서울강동구  서울   강동구  127.125864  37.527367
# 140   서울강북구  서울   강북구  127.027719  37.636956
# 141   서울강서구  서울   강서구  126.851675  37.548156
# 142   서울관악구  서울   관악구  126.953844  37.475386
# 143   서울광진구  서울   광진구  127.084533  37.535739
# 144   서울구로구  서울   구로구  126.889597  37.492650
# 145   서울금천구  서울   금천구  126.904197  37.449108
# 146   서울노원구  서울   노원구  127.058389  37.651461
# 147   서울도봉구  서울   도봉구  127.049522  37.665833
# 148  서울동대문구  서울  동대문구  127.042142  37.571625
# 149   서울동작구  서울   동작구  126.941575  37.509656
# 150   서울마포구  서울   마포구  126.910531  37.560706
# 151  서울서대문구  서울  서대문구  126.938897  37.576367
# 152   서울서초구  서울   서초구  127.034811  37.480786
# 153   서울성동구  서울   성동구  127.039000  37.560611
# 154   서울성북구  서울   성북구  127.020333  37.586383
# 155   서울송파구  서울   송파구  127.107931  37.511756
# 156   서울양천구  서울   양천구  126.868708  37.514231
# 157  서울영등포구  서울  영등포구  126.898342  37.523611
# 158   서울용산구  서울   용산구  126.967522  37.536094
# 159   서울은평구  서울   은평구  126.931242  37.599969
# 160   서울종로구  서울   종로구  126.981642  37.570378
# 161    서울중구  서울    중구  126.999642  37.561003
# 162   서울중랑구  서울   중랑구  127.094778  37.603806

# %%
df_gu_count =  df_sb_seoul.pivot_table(index='구', values='매장명', aggfunc='count').rename(columns={'매장명' : '스타벅스 매장 수'})
df_gu_count.head()
# Out:
#      스타벅스 매장 수
# 구
# 강남구         88
# 강동구         17
# 강북구          6
# 강서구         25
# 관악구         12

# %%
df_loc_seoul.rename(columns={'do' : '도', 'city' : '구', 'latitude' : '위도', 'longitude' : '경도'}, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13476\2161899944.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loc_seoul.rename(columns={'do' : '도', 'city' : '구', 'latitude' : '위도', 'longitude' : '경도'}, inplace=True)

# %%
df_loc_seoul.reset_index(drop=True, inplace=True)
df_loc_seoul.tail()
# Out:
#    docity   도    구          경도         위도
# 20  서울용산구  서울  용산구  126.967522  37.536094
# 21  서울은평구  서울  은평구  126.931242  37.599969
# 22  서울종로구  서울  종로구  126.981642  37.570378
# 23   서울중구  서울   중구  126.999642  37.561003
# 24  서울중랑구  서울  중랑구  127.094778  37.603806

# %%
df_loc_seoul = df_loc_seoul[['도' ,'구', '위도', '경도']]

# %%
df_loc_seoul.tail()
# Out:
#      도    구         위도          경도
# 20  서울  용산구  37.536094  126.967522
# 21  서울  은평구  37.599969  126.931242
# 22  서울  종로구  37.570378  126.981642
# 23  서울   중구  37.561003  126.999642
# 24  서울  중랑구  37.603806  127.094778

# %%
df_sb_seoul_stat = pd.merge(df_loc_seoul, df_gu_count, how='left', on='구')

# %%
df_sb_seoul_stat
# Out:
#      도     구         위도          경도  스타벅스 매장 수
# 0   서울   강남구  37.514575  127.049556         88
# 1   서울   강동구  37.527367  127.125864         17
# 2   서울   강북구  37.636956  127.027719          6
# 3   서울   강서구  37.548156  126.851675         25
# 4   서울   관악구  37.475386  126.953844         12
# 5   서울   광진구  37.535739  127.084533         18
# 6   서울   구로구  37.492650  126.889597         14
# 7   서울   금천구  37.449108  126.904197         12
# 8   서울   노원구  37.651461  127.058389         14
# 9   서울   도봉구  37.665833  127.049522          5
# 10  서울  동대문구  37.571625  127.042142         10
# 11  서울   동작구  37.509656  126.941575         11
# 12  서울   마포구  37.560706  126.910531         36
# 13  서울  서대문구  37.576367  126.938897         22
# 14  서울   서초구  37.480786  127.034811         49
# 15  서울   성동구  37.560611  127.039000         14
# 16  서울   성북구  37.586383  127.020333         15
# 17  서울   송파구  37.511756  127.107931         36
# 18  서울   양천구  37.514231  126.868708         17
# 19  서울  영등포구  37.523611  126.898342         41
# 20  서울   용산구  37.536094  126.967522         25
# 21  서울   은평구  37.599969  126.931242         13
# 22  서울   종로구  37.570378  126.981642         40
# 23  서울    중구  37.561003  126.999642         53
# 24  서울   중랑구  37.603806  127.094778          8

# %%
import folium

# %%
sb_map = folium.Map(location=[37.550823, 126.989502], tiles='Stamen Terrain', zoom_start=11)

for idx in df_sb_seoul.index:
    lat = df_sb_seoul.loc[idx, '위도']
    lng = df_sb_seoul.loc[idx, '경도']
    name = df_sb_seoul.loc[idx, '매장명']

    folium.CircleMarker(location=[lat, lng], popup=name).add_to(sb_map)

sb_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf997d28deb67e9a0ee3809fe7cbba59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf997d28deb67e9a0ee3809fe7cbba59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf997d28deb67e9a0ee3809fe7cbba59 = L.map(
#                 &quot;map_cf997d28deb67e9a0ee3809fe7cbba59&quot;,
#                 {
#                     center: [37.550823, 126.989502],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27fbedecc813bd604d98814ce7c74be8 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cf997d28deb67e9a0ee3809fe7cbba59);
#
#
#             var circle_marker_0c999d9fba79912607fb1d47688faffa = L.circleMarker(
#                 [37.501087, 127.043069],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cf997d28deb67e9a0ee3809fe7cbba59);
#
#
#         var popup_d73798d854d59b8f3561b05e6cb55cca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d72155d2411ee8e908c09b372fb9a47 = $(`&lt;div id=&quot;html_1d72155d2411ee8e908c09b372fb9a47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;역삼아레나빌딩&lt;/div&gt;`)[0];
#                 popup_d73798d854d59b8f3561b05e6cb55cca.setContent(html_1d72155d2411ee8e908c09b372fb9a47);
#
#
#
#         circle_marker_0c999d9fba79912607fb1d47688faffa.bindPopup(popup_d73798d854d59b8f3561b05e6cb55cca)
#         ;
#
#
#
#
#             var circle_marker_fdf13d0d1ff00dac9c019eb7906356a1 = L.circleMarker(
#                 [37.510178, 127.022223],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cf997d28deb67e9a0ee3809fe7cbba59);
#
#
#         var popup_3622f5dba1efa495f3331ee4f9f7adb1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3460acbf8365d3b3c4fa3e98555f784 = $(`&lt;div id=&quot;html_f3460acbf8365d3b3c4fa3e98555f784&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;논현역사거리&lt;/div&gt;`)[0];
#                 popup_3622f5dba1efa495f3331ee4f9f7adb1.setContent(html_f3460acbf8365d3b3c4fa3e98555f784);
#
#
#
#         circle_marker_fdf13d0d1ff00dac9c019eb7906356a1.bindPopup(popup_3622f5dba1efa495f3331ee4f9f7adb1)
#         ;
#
#
#
#
#             var circle_marker_a148358c0add566a6c305f3389e2a2c7 = L.circleMarker(
#                 [37.5139309, 127.0206057],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cf997d28deb67e9a0ee3809fe7cbba59);
#
#
#         var popup_500096e7e5a5470ce077e1d64467133e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_045a90b690b0ef305f3eb4bab6176a61 = $(`&lt;div id=&quot;html_045a90b690b0ef305f3eb4bab6176a61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신사역성일빌딩&lt;/div&gt;`)[0];
#                 popup_500096e7e5a5470ce077e1d64467133e.setContent(html_045a90b690b0ef305f3eb4bab6176a61);
#
#
#
#         circle_marker_a148358c0add566a6c305f3389e2a2c7.bindPopup(popup_500096e7e5a5470ce077e1d64467133e)
#         ;
